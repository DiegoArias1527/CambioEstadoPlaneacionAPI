-- %% [markdown]
-- # [PlaneacionDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [PlaneacionDB]    Script Date: 4/02/2025 4:27:52 p. m. ******/
CREATE DATABASE [PlaneacionDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'PlaneacionDB', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS03\MSSQL\DATA\PlaneacionDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'PlaneacionDB_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS03\MSSQL\DATA\PlaneacionDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [PlaneacionDB] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [PlaneacionDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [PlaneacionDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [PlaneacionDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [PlaneacionDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [PlaneacionDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [PlaneacionDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [PlaneacionDB] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [PlaneacionDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [PlaneacionDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [PlaneacionDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [PlaneacionDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [PlaneacionDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [PlaneacionDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [PlaneacionDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [PlaneacionDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [PlaneacionDB] SET  ENABLE_BROKER 
GO
ALTER DATABASE [PlaneacionDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [PlaneacionDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [PlaneacionDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [PlaneacionDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [PlaneacionDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [PlaneacionDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [PlaneacionDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [PlaneacionDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [PlaneacionDB] SET  MULTI_USER 
GO
ALTER DATABASE [PlaneacionDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [PlaneacionDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [PlaneacionDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [PlaneacionDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [PlaneacionDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [PlaneacionDB] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [PlaneacionDB] SET QUERY_STORE = ON
GO
ALTER DATABASE [PlaneacionDB] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[DetallePlaneacion]

-- %%
USE [PlaneacionDB]
GO

-- %%
/****** Object:  Table [dbo].[DetallePlaneacion]    Script Date: 4/02/2025 4:27:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetallePlaneacion](
	[IdDetallePlaneacion] [uniqueidentifier] NOT NULL,
	[IdPlaneacion] [uniqueidentifier] NOT NULL,
	[IdOrdenServicio] [uniqueidentifier] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdDetallePlaneacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EstadoPlaneacion]

-- %%
/****** Object:  Table [dbo].[EstadoPlaneacion]    Script Date: 4/02/2025 4:27:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EstadoPlaneacion](
	[IdEstadoPlaneacion] [int] IDENTITY(1,1) NOT NULL,
	[Estado] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdEstadoPlaneacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrdenServicio]

-- %%
/****** Object:  Table [dbo].[OrdenServicio]    Script Date: 4/02/2025 4:27:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrdenServicio](
	[IdOrdenServicio] [uniqueidentifier] NOT NULL,
	[NumeroOrdenServicio] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdOrdenServicio] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Planeacion]

-- %%
/****** Object:  Table [dbo].[Planeacion]    Script Date: 4/02/2025 4:27:52 p. m. ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Planeacion](
	[IdPlaneacion] [uniqueidentifier] NOT NULL,
	[IdEstadoPlaneacion] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[IdPlaneacion] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DetallePlaneacion]

-- %%
INSERT [dbo].[DetallePlaneacion] ([IdDetallePlaneacion], [IdPlaneacion], [IdOrdenServicio]) VALUES (N'92c376fb-2f01-4936-bf0b-5d1f6cf722c6', N'711c1703-ab97-4cbf-8fd8-a476894493c7', N'ca45425b-3b3f-4c1b-8e71-a2c0f814fe33')
INSERT [dbo].[DetallePlaneacion] ([IdDetallePlaneacion], [IdPlaneacion], [IdOrdenServicio]) VALUES (N'20798058-ba9d-4691-8bcb-97ab3f65c9b5', N'd66784b2-8f1d-436d-8820-6fb777fb3db4', N'2d6fe158-c297-4750-a5d8-fe5769914ddc')
INSERT [dbo].[DetallePlaneacion] ([IdDetallePlaneacion], [IdPlaneacion], [IdOrdenServicio]) VALUES (N'80e4460f-bc31-4f73-b458-c83368dd7523', N'9e7565a9-a7da-4c03-86ca-cdc462ef929d', N'97ff772c-a451-4cd2-ab72-5821b57859e2')
GO

-- %% [markdown]
-- # [dbo].[EstadoPlaneacion]

-- %%
SET IDENTITY_INSERT [dbo].[EstadoPlaneacion] ON 
INSERT [dbo].[EstadoPlaneacion] ([IdEstadoPlaneacion], [Estado]) VALUES (1, N'Pendiente')
INSERT [dbo].[EstadoPlaneacion] ([IdEstadoPlaneacion], [Estado]) VALUES (2, N'Aprobado')
INSERT [dbo].[EstadoPlaneacion] ([IdEstadoPlaneacion], [Estado]) VALUES (3, N'Rechazado')
INSERT [dbo].[EstadoPlaneacion] ([IdEstadoPlaneacion], [Estado]) VALUES (4, N'En Progreso')
SET IDENTITY_INSERT [dbo].[EstadoPlaneacion] OFF
GO

-- %% [markdown]
-- # [dbo].[OrdenServicio]

-- %%
INSERT [dbo].[OrdenServicio] ([IdOrdenServicio], [NumeroOrdenServicio]) VALUES (N'97ff772c-a451-4cd2-ab72-5821b57859e2', 10770087)
INSERT [dbo].[OrdenServicio] ([IdOrdenServicio], [NumeroOrdenServicio]) VALUES (N'ca45425b-3b3f-4c1b-8e71-a2c0f814fe33', 10770085)
INSERT [dbo].[OrdenServicio] ([IdOrdenServicio], [NumeroOrdenServicio]) VALUES (N'2d6fe158-c297-4750-a5d8-fe5769914ddc', 10770086)
GO

-- %% [markdown]
-- # [dbo].[Planeacion]

-- %%
INSERT [dbo].[Planeacion] ([IdPlaneacion], [IdEstadoPlaneacion]) VALUES (N'd66784b2-8f1d-436d-8820-6fb777fb3db4', 3)
INSERT [dbo].[Planeacion] ([IdPlaneacion], [IdEstadoPlaneacion]) VALUES (N'711c1703-ab97-4cbf-8fd8-a476894493c7', 1)
INSERT [dbo].[Planeacion] ([IdPlaneacion], [IdEstadoPlaneacion]) VALUES (N'9e7565a9-a7da-4c03-86ca-cdc462ef929d', 3)
GO

-- %% [markdown]
-- # [DF__DetallePl__IdDet__52593CB8]

-- %%
ALTER TABLE [dbo].[DetallePlaneacion] ADD  DEFAULT (newid()) FOR [IdDetallePlaneacion]
GO

-- %% [markdown]
-- # [DF__OrdenServ__IdOrd__4BAC3F29]

-- %%
ALTER TABLE [dbo].[OrdenServicio] ADD  DEFAULT (newid()) FOR [IdOrdenServicio]
GO

-- %% [markdown]
-- # [DF__Planeacio__IdPla__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Planeacion] ADD  DEFAULT (newid()) FOR [IdPlaneacion]
GO

-- %% [markdown]
-- # [FK__DetallePl__IdOrd__5441852A]

-- %%
ALTER TABLE [dbo].[DetallePlaneacion]  WITH CHECK ADD FOREIGN KEY([IdOrdenServicio])
REFERENCES [dbo].[OrdenServicio] ([IdOrdenServicio])
GO

-- %% [markdown]
-- # [FK__DetallePl__IdPla__534D60F1]

-- %%
ALTER TABLE [dbo].[DetallePlaneacion]  WITH CHECK ADD FOREIGN KEY([IdPlaneacion])
REFERENCES [dbo].[Planeacion] ([IdPlaneacion])
GO

-- %% [markdown]
-- # [FK__Planeacio__IdEst__4F7CD00D]

-- %%
ALTER TABLE [dbo].[Planeacion]  WITH CHECK ADD FOREIGN KEY([IdEstadoPlaneacion])
REFERENCES [dbo].[EstadoPlaneacion] ([IdEstadoPlaneacion])
GO

-- %% [markdown]
-- # [PlaneacionDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [PlaneacionDB] SET  READ_WRITE 
GO
